# %% [markdown]
# <a href="https://colab.research.google.com/github/Oleksy1121/Machine-Learning/blob/main/ds/Intro_To_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MATPLOTLIB

# %%
import matplotlib
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
matplotlib.__version__
# Out:
# '3.7.1'

# %%
fig = plt.figure() #Objekt figure jest podstawowym obiektem który tworzymy w bibliotece matplotlib
fig.show()

# %%
plt.plot([0,1], [0,3])

# %%
import seaborn as sns
sns.set()

# %%
_=plt.plot([0,1], [0,3])

# %%
plt.plot([0,1], [0,3], label='line', color = 'green')
plt.legend()
plt.xlabel('oś X')
plt.ylabel('oś Y')
_=plt.title('Wykres')

# %%
plt.plot([0,2,1], [0,3,2], label='line', color = 'green')
plt.legend()
plt.xlabel('oś X')
plt.ylabel('oś Y')
_=plt.title('Wykres')

# %%
x = np.arange(-3, 3, 0.1)

# %%
sin_x = np.sin(x)
cos_x = np.cos(x)

# %%
plt.plot(x,sin_x)
_=plt.plot(x,cos_x)

# %% [markdown]
# Tworzenie wielu wykresów

# %%
plt.subplot(121)
plt.plot([1,2,3], [5,3,5])
plt.subplot(122)
plt.plot([1,2,3], [2,3,1],'r--')

# %%
fig = plt.figure(figsize=(10,4))


plt.subplot(131)
plt.title('Wykres 1')
plt.plot([1,2,3], [5,3,5])
plt.ylabel('Y label')
plt.xlabel('X label')

plt.subplot(132)
plt.plot([1,2,3], [2,3,1],'r--')
plt.ylabel('Y label')
plt.xlabel('X label')
plt.title('Wykres 2')

plt.subplot(133)
plt.plot([1,2,3], [4,6,2], 'go')
plt.ylabel('Y label')
plt.xlabel('X label')
plt.title('Wykres 3')
# Out:
# Text(0.5, 1.0, 'Wykres 3')

# %% [markdown]
# Wykresy słupkowe

# %%
plt.bar(x = [1,3,4,6], height=[1.2, 3.4 ,5.6 ,2.3])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x = ['a','b','c','d'], height=[1.2, 3.4 ,5.6 ,2.3])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(y = ['a','b','c','d'], width=[1.2, 3.4 ,5.6 ,2.3])
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Wykresy punktowe

# %%
x1 = np.random.randn(300)
x2= np.random.randn(300)

plt.scatter(x=x1,y=x2)

# %%
x1 = np.random.randn(300)
x2= np.random.randn(300)
x3 = np.random.randn(300)*50

plt.scatter(x=x1,y=x2, s = x3)
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
x1 = np.random.randn(300)
x2= np.random.randn(300)
x3 = np.random.randn(300)*50

plt.scatter(x=x1,y=x2, s = x3, alpha=0.6)

# %% [markdown]
# Wyświetlanie obrazów

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread('office.jpg')
img
# Out:
# array([[[117,  98,  56],
#         [117,  98,  56],
#         [116,  97,  55],
#         ...,
#         [ 98,  82,  48],
#         [ 98,  82,  48],
#         [ 95,  79,  45]],
#
#        [[118,  99,  57],
#         [120, 101,  59],
#         [121, 102,  60],
#         ...,
#         [101,  85,  51],
#         [101,  85,  51],
#         [ 97,  81,  47]],
#
#        [[116,  97,  55],
#         [118,  99,  57],
#         [120, 101,  59],
#         ...,
#         [108,  92,  58],
#         [104,  88,  54],
#         [100,  84,  50]],
#
#        ...,
#
#        [[ 84,  65,  22],
#         [ 86,  67,  24],
#         [ 89,  70,  28],
#         ...,
#         [ 58,  35,   1],
#         [ 58,  35,   1],
#         [ 58,  35,   1]],
#
#        [[ 86,  67,  24],
#         [ 87,  68,  25],
#         [ 89,  70,  28],
#         ...,
#         [ 58,  33,   2],
#         [ 58,  33,   2],
#         [ 57,  32,   1]],
#
#        [[ 88,  69,  26],
#         [ 90,  71,  28],
#         [ 91,  72,  30],
# ...

# %%
img.shape
# Out:
# (426, 640, 3)

# %%
plt.imshow(img)
_=plt.axis('Off')

# %%
plt.subplot(221)
plt.imshow(mpimg.imread('office.jpg'))
_=plt.axis('Off')

plt.subplot(222)
plt.imshow(mpimg.imread('children.jpg'))
_=plt.axis('Off')

plt.subplot(223)
plt.imshow(mpimg.imread('workplace.jpg'))
_=plt.axis('Off')

plt.subplot(224)
plt.imshow(mpimg.imread('business.jpg'))
_=plt.axis('Off')

# %%
fig = plt.figure(figsize = (8,6))

for idx, img in enumerate(['business.jpg', 'office.jpg', 'workplace.jpg', 'children.jpg']):
  plt.subplot(220 + idx + 1)
  plt.imshow(mpimg.imread(img))
  _=plt.axis('Off')

# %% [markdown]
# Style

# %%
x = np.arange(-3,3,0.1)
sin_x = np.sin(x)

plt.plot(x,sin_x)

# %%
plt.style.use('dark_background')

# %%
plt.plot(x,sin_x)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']
